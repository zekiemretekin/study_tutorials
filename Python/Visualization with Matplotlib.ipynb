# %% [markdown]
# ## Visualization with Matplotlib

# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# 73. __Import__ matplotlib.pyplot (as plt) and set the __style__ to __"seaborn"__! __Fill in the gaps!__

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %% [markdown]
# 74. __Create__ the graph below (lineplot for all numerical columns)!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cars.plot(subplots = True, sharex = False, figsize = (15,15))
plt.show()

# %% [markdown]
# 75. __Create__ the graph below (Histogramm for the __"mpg"__ column with 40 bins)!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cars.mpg.plot(kind="hist", title="MPG", xlabel="mpg", ylabel="frequency", figsize=(12,8), bins=40)
plt.show()

# %% [markdown]
# 76. __Create__ the graph below (Scatterplot with __horsepower__ and __mpg__)! __Fill in the gaps!__

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cars.plot(kind = "scatter", x = "mpg", y = "horsepower", figsize = (12,8), c = "cylinders", marker = "x", colormap = "viridis")
plt.title("Horsepower vs MPG", fontsize = 18)
plt.xlabel("horsepower", fontsize = 15)
plt.ylabel("mpg", fontsize = 15)
plt.show()
